# %%
n = ...
c = ...

P.<x>=PolynomialRing(ZZ)
for y in range(20000):
    f = (2^1024-1 + y)*x - x^2-n
    r=f.roots()
    if len(r)!=0:
        print(r)
#     print(r)
# Out:
# [(, 1), (, 1)]

# %%
r1=
gcd(r2,n)
gcd(r1,n)
# Out:
# 

# %%
n
# Out:
# ...
